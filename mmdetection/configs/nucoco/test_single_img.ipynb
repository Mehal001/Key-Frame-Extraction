# %%
from mmdet.apis import inference_detector, init_detector, show_result_pyplot

# Choose to use a config and initialize the detector
config = 'faster_rcnn_r50_caffe_fpn_mstrain_1x_nucoco.py'
# config = 'myconfig_with_subclasses.py'
# Setup a checkpoint file to load
checkpoint = '/home/students/acct1002_15/mmdetection/work_dirs/faster_rcnn_r50_caffe_fpn_mstrain_1x_nucoco/latest.pth'
# checkpoint = '/home/students/acct1002_15/mmdetection/work_dirs/myconfig_with_subclasses/latest.pth'
# initialize the detector
model = init_detector(config, checkpoint)

# img = 'test/00000216.jpg'
img = 'test/00000198.jpg'
result = inference_detector(model, img)

show_result_pyplot(model, img, result, score_thr=0.3)
# Out:
# Use load_from_local loader

# %%
print(result)
# Out:
# [array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([[9.2517181e+02, 4.7512164e+02, 1.0214222e+03, 5.3982294e+02,
#         9.9972552e-01],
#        [7.9627228e+02, 4.7692651e+02, 8.8651807e+02, 5.5351398e+02,
#         9.9946851e-01]], dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32)]

# %%
len(result)
# Out:
# 10

# %%
result[3]
# Out:
# array([[9.2517181e+02, 4.7512164e+02, 1.0214222e+03, 5.3982294e+02,
#         9.9972552e-01],
#        [7.9627228e+02, 4.7692651e+02, 8.8651807e+02, 5.5351398e+02,
#         9.9946851e-01]], dtype=float32)
